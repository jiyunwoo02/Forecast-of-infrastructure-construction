# %%
import pandas as pd

# %%
df = pd.read_csv('seoul.csv',encoding='cp949')
df
# Out:
#      자치구       승하차   노인인구  양로시설수  양로시설정원  양로시설현원  양로시설종사자수  요양시설수 요양시설정원  \
# 0    송파구  15540698  93309      1      12      12         5      8    658
# 1    강남구  17425049  74959      0       0       0         0      4    215
# 2    강동구  11581597  69903      1     124      84        24      8    495
# 3    서초구  11696077  60072      0       0       0         0      4    322
# 4    노원구  12334867  85420      2     124      81        31     11    884
# 5    강서구   8317204  88733      1      25      24        17     18  1,017
# 6   영등포구   6448615  60663      0       0       0         0      1    118
# 7    관악구   9236593  78430      0       0       0         0     10    435
# 8    성북구   6467009  73613      0       0       0         0     16    715
# 9    은평구  12361204  85010      1      25      18         7     15  1,070
# 10  동대문구  10266951  61612      0       0       0         0      4    224
# 11   중랑구   5719284  69341      0       0       0         0     10    859
# 12   구로구   8048800  69201      0       0       0         0     10    913
# 13   종로구  22039837  28311      1      57      45        14      8    347
# 14   마포구   5881397  54002      0       0       0         0      2    284
# 15   동작구  10736494  64928      0       0       0         0      3    190
# 16    중구  16276987  24174      0       0       0         0      2     74
# 17   도봉구   5119901  62009      1      26      21         7     21    848
# 18   강북구   5709043  63313      0       0       0         0      8    503
# 19   광진구   9415599  50311      1     760     554        73      8    487
# 20   양천구   4185988  65541      0       0       0         0     13    656
# 21  서대문구   4959137  53756      0       0       0         0     10    388
# 22   성동구   7078565  45435      0       0       0         0      3    391
# 23   용산구   6693008  39779      0       0       0         0      3    194
# 24   금천구    916795  39314      2      92      79        20     12    586
#
#     요양시설현원  요양시설종사자수  노인복지시설수  노인복지종사자수  경로당  노인교실  노인일자리시설수  노인일자리종사자수  \
# 0      614       441        3        48  172    17         1          9
# 1       63        48        6        94  167    22         1          7
# 2      372       258        3       139  121    10         1          7
# 3      305       215        4       130  141     6         0          0
# 4      808       533        3       125  243    13         1          6
# 5      933       619        5        97  218    25         1          6
# 6      116        87        1        27  174    27         1          6
# 7      405       296        1        33  114    19         1          6
# 8      613       400        6       110  175     9         1          6
# 9      986       639        7       170  154    17         1          6
# 10     208       140        1        41  134    16         1          5
# 11     781       512        5       156  127    11         0          0
# 12     751       499        2        44  199    20         1          6
# 13     325       245        3       111   63     9         1          6
# 14     280       201        4        70  154    11         1          7
# 15     179       117        3        63  140     8         0          0
# 16      72        61        2        66   48     4         0          0
# 17     780       518        5        95  135     9         1          6
# 18     482       322        1        35  100    17         0          0
# 19     453       295        1        63   95    10         1          6
# 20     626       438        4       142  164    23         1          6
# 21     328       247        4        96  111    12         1          6
# 22     359       234        4        82  162    13         0          0
# 23     195       136        2        75   88    20         0          0
# 24     537       384        3       113   73     7         1          6
#
#       노인인프라구축현황  레이블
# 0   1859.818392    0
# 1   2721.161883    1
# 2   1076.926319    0
# 3   3017.865120    1
# 4   2805.535525    1
# 5   2780.743564    1
# 6   1798.280178    0
# 7   4239.670381    1
# 8   2010.822143    0
# 9   2564.482869    1
# 10  2869.890795    1
# 11  1402.169395    0
# 12  2686.771578    1
# 13  5449.431634    1
# 14  1330.266719    0
# 15  1958.879985    0
# 16  2693.304708    1
# 17  2353.161291    0
# 18  2840.409624    1
# 19  2391.334533    0
# 20  2605.823994    1
# 21  2527.724418    1
# 22  2181.135908    0
# 23  1901.279328    0
# 24   754.007182    0

# %%
df.columns
# Out:
# Index(['자치구', '승하차', '노인인구', '양로시설수', '양로시설정원', '양로시설현원', '양로시설종사자수', '요양시설수',
#        '요양시설정원', '요양시설현원', '요양시설종사자수', '노인복지시설수', '노인복지종사자수', '경로당', '노인교실',
#        '노인일자리시설수', '노인일자리종사자수', '노인인프라구축현황', '레이블'],
#       dtype='object')

# %%
import pandas as pd

# Define the conditions and labels
conditions = [700, 1400, 2100, float('inf')]
labels = ['Low', 'Medium', 'High']

# Create the labels based on the conditions
df['레이블'] = pd.cut(df['노인인프라구축현황'], bins=conditions, labels=labels)

# %%
df
# Out:
#      자치구       승하차   노인인구  양로시설수  양로시설정원  양로시설현원  양로시설종사자수  요양시설수 요양시설정원  \
# 0    송파구  15540698  93309      1      12      12         5      8    658
# 1    강남구  17425049  74959      0       0       0         0      4    215
# 2    강동구  11581597  69903      1     124      84        24      8    495
# 3    서초구  11696077  60072      0       0       0         0      4    322
# 4    노원구  12334867  85420      2     124      81        31     11    884
# 5    강서구   8317204  88733      1      25      24        17     18  1,017
# 6   영등포구   6448615  60663      0       0       0         0      1    118
# 7    관악구   9236593  78430      0       0       0         0     10    435
# 8    성북구   6467009  73613      0       0       0         0     16    715
# 9    은평구  12361204  85010      1      25      18         7     15  1,070
# 10  동대문구  10266951  61612      0       0       0         0      4    224
# 11   중랑구   5719284  69341      0       0       0         0     10    859
# 12   구로구   8048800  69201      0       0       0         0     10    913
# 13   종로구  22039837  28311      1      57      45        14      8    347
# 14   마포구   5881397  54002      0       0       0         0      2    284
# 15   동작구  10736494  64928      0       0       0         0      3    190
# 16    중구  16276987  24174      0       0       0         0      2     74
# 17   도봉구   5119901  62009      1      26      21         7     21    848
# 18   강북구   5709043  63313      0       0       0         0      8    503
# 19   광진구   9415599  50311      1     760     554        73      8    487
# 20   양천구   4185988  65541      0       0       0         0     13    656
# 21  서대문구   4959137  53756      0       0       0         0     10    388
# 22   성동구   7078565  45435      0       0       0         0      3    391
# 23   용산구   6693008  39779      0       0       0         0      3    194
# 24   금천구    916795  39314      2      92      79        20     12    586
#
#     요양시설현원  요양시설종사자수  노인복지시설수  노인복지종사자수  경로당  노인교실  노인일자리시설수  노인일자리종사자수  \
# 0      614       441        3        48  172    17         1          9
# 1       63        48        6        94  167    22         1          7
# 2      372       258        3       139  121    10         1          7
# 3      305       215        4       130  141     6         0          0
# 4      808       533        3       125  243    13         1          6
# 5      933       619        5        97  218    25         1          6
# 6      116        87        1        27  174    27         1          6
# 7      405       296        1        33  114    19         1          6
# 8      613       400        6       110  175     9         1          6
# 9      986       639        7       170  154    17         1          6
# 10     208       140        1        41  134    16         1          5
# 11     781       512        5       156  127    11         0          0
# 12     751       499        2        44  199    20         1          6
# 13     325       245        3       111   63     9         1          6
# 14     280       201        4        70  154    11         1          7
# 15     179       117        3        63  140     8         0          0
# 16      72        61        2        66   48     4         0          0
# 17     780       518        5        95  135     9         1          6
# 18     482       322        1        35  100    17         0          0
# 19     453       295        1        63   95    10         1          6
# 20     626       438        4       142  164    23         1          6
# 21     328       247        4        96  111    12         1          6
# 22     359       234        4        82  162    13         0          0
# 23     195       136        2        75   88    20         0          0
# 24     537       384        3       113   73     7         1          6
#
#       노인인프라구축현황     레이블
# 0   1859.818392  Medium
# 1   2721.161883    High
# 2   1076.926319     Low
# 3   3017.865120    High
# 4   2805.535525    High
# 5   2780.743564    High
# 6   1798.280178  Medium
# 7   4239.670381    High
# 8   2010.822143  Medium
# 9   2564.482869    High
# 10  2869.890795    High
# 11  1402.169395  Medium
# 12  2686.771578    High
# 13  5449.431634    High
# 14  1330.266719     Low
# 15  1958.879985  Medium
# 16  2693.304708    High
# 17  2353.161291    High
# 18  2840.409624    High
# 19  2391.334533    High
# 20  2605.823994    High
# 21  2527.724418    High
# 22  2181.135908    High
# 23  1901.279328  Medium
# 24   754.007182     Low

# %%
df.columns
# Out:
# Index(['자치구', '승하차', '노인인구', '양로시설수', '양로시설정원', '양로시설현원', '양로시설종사자수', '요양시설수',
#        '요양시설정원', '요양시설현원', '요양시설종사자수', '노인복지시설수', '노인복지종사자수', '경로당', '노인교실',
#        '노인일자리시설수', '노인일자리종사자수', '노인인프라구축현황', '레이블'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error

# %%
import pandas as pd
import re

# Preprocess '노인인프라구축현황' column
df['노인인프라구축현황'] = df['노인인프라구축현황'].apply(lambda x: re.sub(r'\D', '', str(x)))
df['노인인프라구축현황'] = df['노인인프라구축현황'].astype(float)

conditions = [700, 1400, 2100, float('inf')]
labels = ['Low', 'Medium', 'High']

# Create the labels based on the conditions
df['레이블'] = pd.cut(df['노인인프라구축현황'], bins=conditions, labels=labels)

# 예측에 사용할 특성 열 선택
features = ['자치구', '승하차', '노인인구', '양로시설수', '양로시설정원', '양로시설현원', '양로시설종사자수',
            '요양시설수', '요양시설현원', '요양시설종사자수', '노인복지시설수', '노인복지종사자수',
            '경로당', '노인교실', '노인일자리시설수', '노인일자리종사자수', '노인인프라구축현황']

# 원-핫 인코딩 수행
df_encoded = pd.get_dummies(df, columns=['자치구'])

# 예측에 사용할 특성 열 선택
features_encoded = df_encoded.columns.drop(['레이블'])

# 훈련 데이터와 테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df_encoded[features_encoded], df_encoded['레이블'], test_size=0.2, random_state=42)

# 로지스틱 회귀 모델 구축
model = LogisticRegression()
model.fit(X_train, y_train)

# 예측 수행
y_pred = model.predict(X_test)

# 정확도 평가
accuracy = accuracy_score(y_test, y_pred)
print('정확도:', accuracy)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("평균 제곱 오차(MSE): ", mse)
print("결정 계수(R^2): ", r2)
print("평균 절대 오차(MAE): ", mae)
print("평균 제곱근 오차(RMSE): ", rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14136/2372340303.py in <module>
#      28 # 로지스틱 회귀 모델 구축
#      29 model = LogisticRegression()
# ---> 30 model.fit(X_train, y_train)
#      31
#      32 # 예측 수행
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1239         classes_ = self.classes_
#    1240         if n_classes < 2:
# -> 1241             raise ValueError(
#    1242                 "This solver needs samples of at least 2 classes"
#    1243                 " in the data, but the data contains only one"
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 'High'

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# f1-score 계산
f1 = f1_score(y_test, y_pred)
print("f1-score:", f1)

# 정밀도 계산
precision = precision_score(y_test, y_pred)
print("정밀도:", precision)

# 재현율 계산
recall = recall_score(y_test, y_pred)
print("재현율:", recall)
# Out:
# f1-score: 0.6666666666666666
# 정밀도: 0.5
# 재현율: 1.0

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# 예측에 사용할 특성 열 선택
features = ['자치구', '승하차', '노인인구', '양로시설수','양로시설정원','양로시설현원','양로시설종사자수','요양시설수',
            '요양시설정원','요양시설현원','요양시설종사자수','노인복지시설수','노인복지종사자수',
            '경로당','노인교실','노인일자리시설수','노인일자리종사자수','노인인프라구축현황']

# 원-핫 인코딩 수행
df_encoded = pd.get_dummies(df, columns=['자치구'])

# 예측에 사용할 특성 열 선택
features_encoded = df_encoded.columns.drop(['레이블'])

# 훈련 데이터와 테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df_encoded[features_encoded], df_encoded['레이블'], test_size=0.2, random_state=42)

# 모델 생성 및 훈련
model = LinearRegression()
model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("평균 제곱 오차(MSE): ", mse)
print("결정 계수(R^2): ", r2)
print("평균 절대 오차(MAE): ", mae)
print("평균 제곱근 오차(RMSE): ", rmse)
# Out:
# 평균 제곱 오차(MSE):  1.13550866045089
# 결정 계수(R^2):  -6.09692912781806
# 평균 절대 오차(MAE):  0.8815609304850772
# 평균 제곱근 오차(RMSE):  1.0656024870705256

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# 랜덤 포레스트 회귀 모델 구축
model = RandomForestRegressor(n_estimators=100, random_state=42)

# 모델 학습
model.fit(X_train, y_train)

# 모델 예측
y_pred = model.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("평균 제곱 오차(MSE): ", mse)
print("결정 계수(R^2): ", r2)
print("평균 절대 오차(MAE): ", mae)
print("평균 제곱근 오차(RMSE): ", rmse)
# Out:
# 평균 제곱 오차(MSE):  0.0
# 결정 계수(R^2):  1.0
# 평균 절대 오차(MAE):  0.0
# 평균 제곱근 오차(RMSE):  0.0

# %%
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# '자치구' 열을 기준으로 원-핫 인코딩수행.
df_encoded = pd.get_dummies(df, columns=['자치구'])

# 예측에 사용할 특성 열 선택, '레이블' 열을 제외한 모든 열이 특성 열로 선택
features_encoded = df_encoded.columns.drop(['레이블'])

# training 데이터와 test 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df_encoded[features_encoded], df_encoded['레이블'], test_size=0.2, random_state=42)

# AdaBoost classifier 생성
ada_boost = AdaBoostClassifier()
ada_boost.fit(X_train, y_train)

# 테스트 데이터 예측 생성
y_pred = ada_boost.predict(X_test)

# 모델 평가
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("평균 제곱 오차(MSE): ", mse)
print("결정 계수(R^2): ", r2)
print("평균 절대 오차(MAE): ", mae)
print("평균 제곱근 오차(RMSE): ", rmse)
# Out:
# 평균 제곱 오차(MSE):  0.0
# 결정 계수(R^2):  1.0
# 평균 절대 오차(MAE):  0.0
# 평균 제곱근 오차(RMSE):  0.0

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
# 원-핫 인코딩 수행
df_encoded = pd.get_dummies(df, columns=['자치구'])

# 예측에 사용할 특성 열 선택
features_encoded = df_encoded.columns.drop(['레이블'])

# 훈련 데이터와 테스트 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df_encoded[features_encoded], df_encoded['레이블'], test_size=0.2, random_state=42)

# GBM 모델 생성 및 훈련
gbm = GradientBoostingClassifier(random_state=42)
gbm.fit(X_train, y_train)

# 테스트 데이터에 대한 예측 생성
predictions = gbm.predict(X_test)

# 정확도 평가
accuracy = accuracy_score(y_test, predictions)
print('정확도:', accuracy)

# 모델 평가
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
rmse = np.sqrt(mean_squared_error(y_test, predictions))

print("평균 제곱 오차(MSE): ", mse)
print("결정 계수(R^2): ", r2)
print("평균 절대 오차(MAE): ", mae)
print("평균 제곱근 오차(RMSE): ", rmse)
# Out:
# 정확도: 1.0
# 평균 제곱 오차(MSE):  0.0
# 결정 계수(R^2):  1.0
# 평균 절대 오차(MAE):  0.0
# 평균 제곱근 오차(RMSE):  0.0
