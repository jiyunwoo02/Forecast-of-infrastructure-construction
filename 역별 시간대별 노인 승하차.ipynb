# %%
import pandas as pd

# %%
df1 = pd.read_csv('노인 승하차(1).csv', encoding = 'cp949')
df2 = pd.read_csv('역별 시간대별 승하차인원(1).csv', encoding = 'cp949')

# %%
df1
# Out:
#      호선명   역번호   역명 승하차구분  승하차인원수
# 0      1   150  서울역    승차  118173
# 1      1   150  서울역    하차  111415
# 2      1   151   시청    승차   47686
# 3      1   151   시청    하차   46713
# 4      1   152   종각    승차   87092
# ..   ...   ...  ...   ...     ...
# 539    8  2826   수진    하차   30481
# 540    8  2827   모란    승차   38514
# 541    8  2827   모란    하차   30439
# 542    8  2828  남위례    승차   13952
# 543    8  2828  남위례    하차   14047
#
# [544 rows x 5 columns]

# %%
df2
# Out:
#      호선명   역번호   역명 승하차구분  06시간대이전  06-07시간대  07-08시간대  08-09시간대  09-10시간대
# 0      1   150  서울역    승차       98       102       216       281       298  \
# 1      1   150  서울역    하차      108       286       354       443       513
# 2      1   151   시청    승차       19        40        39        47        88
# 3      1   151   시청    하차       80       122       261       314       272
# 4      1   152   종각    승차       35        43        34        84       144
# ..   ...   ...  ...   ...      ...       ...       ...       ...       ...
# 543    8  2828  남위례    하차       12        40        59        41        31
# 544    3   321  충무로    승차        0         0         0         0         0
# 545    3   321  충무로    하차        0         0         0         0         0
# 546    6  2615  연신내    승차        0         0         0         0         0
# 547    6  2615  연신내    하차        0         0         0         0         0
#
#      10-11시간대  ...  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대
# ...

# %% [markdown]
# # 병합 해결

# %%
merged_data = df1.merge(df2, on=(['호선명', '역번호', '역명', '승하차구분']))
merged_data
# Out:
#      호선명   역번호   역명 승하차구분  승하차인원수  06시간대이전  06-07시간대  07-08시간대  08-09시간대
# 0      1   150  서울역    승차  118173       98       102       216       281  \
# 1      1   150  서울역    하차  111415      108       286       354       443
# 2      1   151   시청    승차   47686       19        40        39        47
# 3      1   151   시청    하차   46713       80       122       261       314
# 4      1   152   종각    승차   87092       35        43        34        84
# ..   ...   ...  ...   ...     ...      ...       ...       ...       ...
# 539    8  2826   수진    하차   30481       10        59        47        93
# 540    8  2827   모란    승차   38514       28        43        48        63
# 541    8  2827   모란    하차   30439       13        50        40        68
# 542    8  2828  남위례    승차   13952       13        33        58        82
# 543    8  2828  남위례    하차   14047       12        40        59        41
#
#      09-10시간대  ...  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대
# ...

# %%
merged_data.to_csv('역별 시간대별 노인 승하차.csv', encoding='cp949', index = False)
